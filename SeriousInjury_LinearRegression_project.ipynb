# %% [markdown]
# <a href="https://colab.research.google.com/github/Rishisrv1470/Data-Analysis-Data-Science-project/blob/main/SeriousInjury_LinearRegression_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
ds=pd.read_csv('/content/drive/MyDrive/datasheet/serious-injury-outcome-indicators-2000-2020-CSV (1).csv')

# %%
ds
# Out:
#      Series_reference   Period            Type  Data_value   Lower_CI  \
# 0               W_A11  2000-02  Moving average   59.666667  50.925823
# 1               W_A11  2001-03  Moving average   60.000000  51.234775
# 2               W_A11  2002-04  Moving average   59.000000  50.308125
# 3               W_A11  2003-05  Moving average   59.000000  50.308125
# 4               W_A11  2004-06  Moving average   61.333333  52.471252
# ...               ...      ...             ...         ...        ...
# 2743              p21     2014     Single year   46.000000  32.706878
# 2744              p21     2015     Single year   41.000000  28.450107
# 2745              p21     2016     Single year   36.000000  24.240216
# 2746              p21     2017     Single year   40.000000  27.604099
# 2747              p21     2018     Single year   41.000000  28.450107
#
#        Upper_CI     Units Indicator       Cause Validation Population  \
# ...

# %%
ds.isnull().sum()
# Out:
# Series_reference    0
# Period              0
# Type                0
# Data_value          0
# Lower_CI            0
# Upper_CI            0
# Units               0
# Indicator           0
# Cause               0
# Validation          0
# Population          0
# Age                 0
# Severity            0
# dtype: int64

# %%
ds.dropna().sum()
# Out:
# Series_reference    W_A11W_A11W_A11W_A11W_A11W_A11W_A11W_A11W_A11W...
# Period              2000-022001-032002-042003-052004-062005-072006...
# Type                Moving averageMoving averageMoving averageMovi...
# Data_value                                             1347943.330687
# Lower_CI                                               1276929.781299
# Upper_CI                                               1418956.880076
# Units               InjuriesInjuriesInjuriesInjuriesInjuriesInjuri...
# Indicator           NumberNumberNumberNumberNumberNumberNumberNumb...
# Cause               AssaultAssaultAssaultAssaultAssaultAssaultAssa...
# Validation          ValidatedValidatedValidatedValidatedValidatedV...
# Population          Whole popWhole popWhole popWhole popWhole popW...
# Age                 All agesAll agesAll agesAll agesAll agesAll ag...
# Severity            FatalFatalFatalFatalFatalFatalFatalFatalFatalF...
# dtype: object

# %%
ds.duplicated().sum()
# Out:
# 0

# %%
ds.describe()
# Out:
#          Data_value      Lower_CI      Upper_CI
# count   2748.000000   2748.000000   2748.000000
# mean     490.517951    464.676049    516.359854
# std     1407.607086   1375.839232   1439.777285
# min        0.713333      0.191677      0.801232
# 25%       15.380863     13.279127     17.368272
# 50%       63.000000     50.923845     72.926641
# 75%      308.000000    273.602772    342.397228
# max    14141.000000  13907.929047  14374.070953

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2748 entries, 0 to 2747
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Series_reference  2748 non-null   object
#  1   Period            2748 non-null   object
#  2   Type              2748 non-null   object
#  3   Data_value        2748 non-null   float64
#  4   Lower_CI          2748 non-null   float64
#  5   Upper_CI          2748 non-null   float64
#  6   Units             2748 non-null   object
#  7   Indicator         2748 non-null   object
#  8   Cause             2748 non-null   object
#  9   Validation        2748 non-null   object
#  10  Population        2748 non-null   object
#  11  Age               2748 non-null   object
#  12  Severity          2748 non-null   object
# dtypes: float64(3), object(10)
# memory usage: 279.2+ KB

# %%
ds.drop(['Series_reference','Period','Type','Units','Indicator','Cause','Validation','Population','Age','Severity'],axis=1,inplace=True)

# %%
ds
# Out:
#       Data_value   Lower_CI   Upper_CI
# 0      59.666667  50.925823  68.407510
# 1      60.000000  51.234775  68.765225
# 2      59.000000  50.308125  67.691875
# 3      59.000000  50.308125  67.691875
# 4      61.333333  52.471252  70.195415
# ...          ...        ...        ...
# 2743   46.000000  32.706878  59.293122
# 2744   41.000000  28.450107  53.549893
# 2745   36.000000  24.240216  47.759784
# 2746   40.000000  27.604099  52.395901
# 2747   41.000000  28.450107  53.549893
#
# [2748 rows x 3 columns]

# %%
ds.astype(int)
# Out:
#       Data_value  Lower_CI  Upper_CI
# 0             59        50        68
# 1             60        51        68
# 2             59        50        67
# 3             59        50        67
# 4             61        52        70
# ...          ...       ...       ...
# 2743          46        32        59
# 2744          41        28        53
# 2745          36        24        47
# 2746          40        27        52
# 2747          41        28        53
#
# [2748 rows x 3 columns]

# %%
ds.shape
# Out:
# (2748, 3)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.plot(ds)

# %%
plt.hist(ds)
# Out:
# (array([[2.526e+03, 1.120e+02, 3.800e+01, 2.200e+01, 7.000e+00, 1.400e+01,
#          1.400e+01, 8.000e+00, 3.000e+00, 4.000e+00],
#         [2.537e+03, 1.070e+02, 3.800e+01, 1.600e+01, 9.000e+00, 1.400e+01,
#          1.300e+01, 8.000e+00, 5.000e+00, 1.000e+00],
#         [2.517e+03, 1.200e+02, 3.400e+01, 2.600e+01, 8.000e+00, 1.300e+01,
#          1.500e+01, 8.000e+00, 3.000e+00, 4.000e+00]]),
#  array([1.91677159e-01, 1.43757960e+03, 2.87496753e+03, 4.31235546e+03,
#         5.74974339e+03, 7.18713132e+03, 8.62451924e+03, 1.00619072e+04,
#         1.14992951e+04, 1.29366830e+04, 1.43740710e+04]),
#  <a list of 3 BarContainer objects>)

# %%
sns.scatterplot(ds)
# Out:
# <Axes: >

# %%
x_raw=ds[['Lower_CI','Upper_CI']].values
y=ds[['Data_value']].values

# %%
x_raw.shape,y.shape
# Out:
# ((2748, 2), (2748, 1))

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scale=MinMaxScaler()

# %%
x=scale.fit_transform(x_raw)

# %%
y
# Out:
# array([[59.66666667],
#        [60.        ],
#        [59.        ],
#        ...,
#        [36.        ],
#        [40.        ],
#        [41.        ]])

# %%
x
# Out:
# array([[0.00364791, 0.00470361],
#        [0.00367012, 0.0047285 ],
#        [0.00360349, 0.00465382],
#        ...,
#        [0.00172915, 0.00326708],
#        [0.00197102, 0.00358963],
#        [0.00203185, 0.00366991]])

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.3)

# %%
y_train.astype(int),y_test.astype(int)
# Out:
# (array([[    4],
#         [    7],
#         [   52],
#         [   68],
#         [   40],
#         [  241],
#         [   70],
#         [ 4254],
#         [   33],
#         [  635],
#         [  575],
#         [  302],
#         [   25],
#         [   79],
#         [    1],
#         [  458],
#         [   67],
#         [   37],
#         [   89],
#         [    6],
#         [ 1180],
#         [  345],
#         [  323],
#         [   13],
#         [    7],
#         [   55],
#         [   29],
#         [    1],
#         [  349],
#         [  616],
#         [  307],
#         [ 1224],
#         [  108],
#         [    5],
#         [ 2145],
#         [   23],
#         [    7],
#         [   56],
#         [  260],
#         [  237],
#         [  218],
#         [   44],
#         [   55],
#         [ 1864],
#         [    6],
#         [   12],
#         [   19],
#         [    9],
#         [   57],
#         [   77],
#         [ 1264],
#         [  115],
# ...

# %%
y_train.ravel(),y_test.ravel()
# Out:
# (array([4.34662050e+00, 7.74105447e+00, 5.20000000e+01, 6.80742966e+01,
#         4.00000000e+01, 2.41000000e+02, 7.00000000e+01, 4.25400000e+03,
#         3.38713362e+01, 6.35000000e+02, 5.75000000e+02, 3.02000000e+02,
#         2.56782768e+01, 7.96385384e+01, 1.73732636e+00, 4.58000000e+02,
#         6.70701300e+01, 3.75852597e+01, 8.90000000e+01, 6.88050357e+00,
#         1.18035652e+03, 3.45000000e+02, 3.23000000e+02, 1.30114608e+01,
#         7.46420572e+00, 5.59056084e+01, 2.90000000e+01, 1.19074701e+00,
#         3.49000000e+02, 6.16000000e+02, 3.07000000e+02, 1.22431586e+03,
#         1.08000000e+02, 5.49643479e+00, 2.14500000e+03, 2.34608083e+01,
#         7.00000000e+00, 5.63333333e+01, 2.60495325e+02, 2.37481090e+02,
#         2.18000000e+02, 4.40000000e+01, 5.50000000e+01, 1.86400000e+03,
#         6.27999332e+00, 1.23981820e+01, 1.92816711e+01, 9.39417246e+00,
#         5.70000000e+01, 7.74768785e+01, 1.26400000e+03, 1.15333333e+02,
# ...

# %%
x_train.shape,y_train.shape
# Out:
# ((824, 2), (824, 1))

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
print(r2_score(y_test,y_pred))
# Out:
# 1.0
