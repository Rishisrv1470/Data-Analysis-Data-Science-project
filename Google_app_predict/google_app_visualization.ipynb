# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
ds=pd.read_csv('googleplaystore.csv')

# %%
ds
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
data=ds[0:250]

# %%
data
# Out:
#                                                    App        Category  \
# 0       Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN
# 1                                  Coloring book moana  ART_AND_DESIGN
# 2    U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 3                                Sketch - Draw & Paint  ART_AND_DESIGN
# 4                Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN
# ..                                                 ...             ...
# 245                           Xero Accounting Software        BUSINESS
# 246            MailChimp - Email, Marketing Automation        BUSINESS
# 247               Crew - Free Messaging and Scheduling        BUSINESS
# 248                      Asana: organize team projects        BUSINESS
# 249                                   Google Analytics        BUSINESS
#
#      Rating Reviews                Size     Installs  Type Price  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             250 non-null    object
#  1   Category        250 non-null    object
#  2   Rating          239 non-null    float64
#  3   Reviews         250 non-null    object
#  4   Size            250 non-null    object
#  5   Installs        250 non-null    object
#  6   Type            250 non-null    object
#  7   Price           250 non-null    object
#  8   Content Rating  250 non-null    object
#  9   Genres          250 non-null    object
#  10  Last Updated    250 non-null    object
#  11  Current Ver     249 non-null    object
#  12  Android Ver     250 non-null    object
# dtypes: float64(1), object(12)
# memory usage: 25.5+ KB

# %%
data.describe()
# Out:
#            Rating
# count  239.000000
# mean     4.311297
# std      0.334309
# min      3.100000
# 25%      4.100000
# 50%      4.400000
# 75%      4.600000
# max      4.900000

# %%
data.isnull().sum()
# Out:
# App                0
# Category           0
# Rating            11
# Reviews            0
# Size               0
# Installs           0
# Type               0
# Price              0
# Content Rating     0
# Genres             0
# Last Updated       0
# Current Ver        1
# Android Ver        0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 3

# %%
sns.countplot(data,y='Genres')
# Out:
# <Axes: xlabel='count', ylabel='Genres'>

# %%
sns.countplot(data=data,x='Rating')
# Out:
# <Axes: xlabel='Rating', ylabel='count'>

# %%
sns.countplot(data=data,x='Type')
# Out:
# <Axes: xlabel='Type', ylabel='count'>

# %%
sns.countplot(data=data,x='Price')
# Out:
# <Axes: xlabel='Price', ylabel='count'>

# %%
sns.countplot(data=data,x='Content Rating')
# Out:
# <Axes: xlabel='Content Rating', ylabel='count'>

# %%
sns.countplot(data=data,y='Android Ver')
# Out:
# <Axes: xlabel='count', ylabel='Android Ver'>

# %%
sns.lineplot(data=data,y='Category',x='Rating')
# Out:
# <Axes: xlabel='Rating', ylabel='Category'>

# %%
sns.scatterplot(data=data,y='Category',x='Rating')
# Out:
# <Axes: xlabel='Rating', ylabel='Category'>

# %%
sns.barplot(data=data,y='Category',x='Rating')
# Out:
# <Axes: xlabel='Rating', ylabel='Category'>

# %%
sns.lineplot(data=data,y='Category',x='Type')
# Out:
# <Axes: xlabel='Type', ylabel='Category'>

# %%
sns.scatterplot(data=data,y='Category',x='Type')
# Out:
# <Axes: xlabel='Type', ylabel='Category'>

# %%
sns.lineplot(data=data,y='Category',x='Price')
# Out:
# <Axes: xlabel='Price', ylabel='Category'>

# %%
sns.scatterplot(data=data,y='Category',x='Price')
# Out:
# <Axes: xlabel='Price', ylabel='Category'>

# %%
sns.lineplot(data=data,x='Content Rating',y='Category')
# Out:
# <Axes: xlabel='Content Rating', ylabel='Category'>

# %%
sns.scatterplot(data=data,x='Content Rating',y='Category')
# Out:
# <Axes: xlabel='Content Rating', ylabel='Category'>

# %%
sns.lineplot(data=data,x='Content Rating',y='Android Ver')
# Out:
# <Axes: xlabel='Content Rating', ylabel='Android Ver'>

# %%
sns.scatterplot(data=data,x='Content Rating',y='Android Ver')
# Out:
# <Axes: xlabel='Content Rating', ylabel='Android Ver'>

# %%
sns.lineplot(data=data,y='Rating',x='Type')
# Out:
# <Axes: xlabel='Type', ylabel='Rating'>

# %%
sns.scatterplot(data=data,y='Rating',x='Type')
# Out:
# <Axes: xlabel='Type', ylabel='Rating'>

# %%
sns.barplot(data=data,y='Rating',x='Type')
# Out:
# <Axes: xlabel='Type', ylabel='Rating'>

# %%
sns.lineplot(data=data,y='Rating',x='Price')
# Out:
# <Axes: xlabel='Price', ylabel='Rating'>

# %%
sns.scatterplot(data=data,y='Rating',x='Price')
# Out:
# <Axes: xlabel='Price', ylabel='Rating'>

# %%
sns.barplot(data=data,y='Rating',x='Price')
# Out:
# <Axes: xlabel='Price', ylabel='Rating'>

# %%
sns.lineplot(data=data,y='Rating',x='Content Rating')
# Out:
# <Axes: xlabel='Content Rating', ylabel='Rating'>

# %%
sns.scatterplot(data=data,y='Rating',x='Content Rating')
# Out:
# <Axes: xlabel='Content Rating', ylabel='Rating'>

# %%
sns.barplot(data=data,y='Rating',x='Content Rating')
# Out:
# C:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))
# <Axes: xlabel='Content Rating', ylabel='Rating'>

# %%
sns.lineplot(data=data,x='Rating',y='Android Ver')
# Out:
# <Axes: xlabel='Rating', ylabel='Android Ver'>

# %%
sns.scatterplot(data=data,x='Rating',y='Android Ver')
# Out:
# <Axes: xlabel='Rating', ylabel='Android Ver'>

# %%
sns.barplot(data=data,x='Rating',y='Android Ver')
# Out:
# C:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))
# <Axes: xlabel='Rating', ylabel='Android Ver'>

# %%
sns.lineplot(data=data,x='Type',y='Price')
# Out:
# <Axes: xlabel='Type', ylabel='Price'>

# %%
sns.scatterplot(data=data,x='Type',y='Price')
# Out:
# <Axes: xlabel='Type', ylabel='Price'>

# %%
sns.lineplot(data=data,x='Type',y='Content Rating')
# Out:
# <Axes: xlabel='Type', ylabel='Content Rating'>

# %%
sns.scatterplot(data=data,x='Type',y='Content Rating')
# Out:
# <Axes: xlabel='Type', ylabel='Content Rating'>

# %%
sns.lineplot(data=data,x='Type',y='Android Ver')
# Out:
# <Axes: xlabel='Type', ylabel='Android Ver'>

# %%
sns.scatterplot(data=data,x='Type',y='Android Ver')
# Out:
# <Axes: xlabel='Type', ylabel='Android Ver'>
