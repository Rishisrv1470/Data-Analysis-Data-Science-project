# %%
#importing the modules
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
ds=pd.read_csv('gold.csv')

# %%
ds
# Out:
#            Date    Open    High     Low   Close  Adj Close  Volume
# 0    2022-06-13  6346.0  6350.0  6295.0  6323.0     6323.0   17820
# 1    2022-06-14  6133.0  6175.0  6120.0  6165.0     6165.0   12430
# 2    2022-06-15  6133.0  6157.0  6118.0  6135.0     6135.0    5470
# 3    2022-06-16  6169.0  6181.0  6159.0  6159.0     6159.0    2630
# 4    2022-06-17  6152.0  6215.0  6131.0  6212.0     6212.0   15660
# ..          ...     ...     ...     ...     ...        ...     ...
# 240  2023-06-05  6778.0  6780.0  6750.0  6761.0     6761.0   56380
# 241  2023-06-06  6776.0  6794.0  6774.0  6781.0     6781.0    5470
# 242  2023-06-07  6795.0  6800.0  6781.0  6790.0     6790.0    4500
# 243  2023-06-08  6746.0  6765.0  6746.0  6759.0     6759.0   21250
# 244  2023-06-09  6773.0  6793.0  6768.0  6793.0     6793.0    8250
#
# [245 rows x 7 columns]

# %%
ds.describe()
# Out:
#               Open         High          Low       Close
# count   245.000000   245.000000   245.000000   245.00000
# mean   6225.497959  6241.865306  6207.530612  6226.00000
# std     268.056799   267.856860   269.821321   271.09411
# min    5848.000000  5850.000000  5806.000000  5808.00000
# 25%    6039.000000  6070.000000  6028.000000  6050.00000
# 50%    6146.000000  6160.000000  6126.000000  6142.00000
# 75%    6309.000000  6309.000000  6270.000000  6283.00000
# max    6847.000000  6851.000000  6820.000000  6829.00000

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245 entries, 0 to 244
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    245 non-null    float64
#  1   High    245 non-null    float64
#  2   Low     245 non-null    float64
#  3   Close   245 non-null    float64
# dtypes: float64(4)
# memory usage: 7.8 KB

# %%
len(ds)
# Out:
# 245

# %%
ds.dtypes
# Out:
# Open     float64
# High     float64
# Low      float64
# Close    float64
# dtype: object

# %%
#checking for the duplicate value
ds.duplicated().sum()
# Out:
# 0

# %%
#checking for the missing value
ds.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
ds.drop(['Date','Volume','Adj Close'],axis=1,inplace=True)

# %%
ds
# Out:
#        Open    High     Low   Close
# 0    6346.0  6350.0  6295.0  6323.0
# 1    6133.0  6175.0  6120.0  6165.0
# 2    6133.0  6157.0  6118.0  6135.0
# 3    6169.0  6181.0  6159.0  6159.0
# 4    6152.0  6215.0  6131.0  6212.0
# ..      ...     ...     ...     ...
# 240  6778.0  6780.0  6750.0  6761.0
# 241  6776.0  6794.0  6774.0  6781.0
# 242  6795.0  6800.0  6781.0  6790.0
# 243  6746.0  6765.0  6746.0  6759.0
# 244  6773.0  6793.0  6768.0  6793.0
#
# [245 rows x 4 columns]

# %%
x_raw=ds[['Open','High','Low']]

# %%
x_raw
# Out:
#        Open    High     Low
# 0    6346.0  6350.0  6295.0
# 1    6133.0  6175.0  6120.0
# 2    6133.0  6157.0  6118.0
# 3    6169.0  6181.0  6159.0
# 4    6152.0  6215.0  6131.0
# ..      ...     ...     ...
# 240  6778.0  6780.0  6750.0
# 241  6776.0  6794.0  6774.0
# 242  6795.0  6800.0  6781.0
# 243  6746.0  6765.0  6746.0
# 244  6773.0  6793.0  6768.0
#
# [245 rows x 3 columns]

# %%
y=ds[['Close']]

# %%
y
# Out:
#       Close
# 0    6323.0
# 1    6165.0
# 2    6135.0
# 3    6159.0
# 4    6212.0
# ..      ...
# 240  6761.0
# 241  6781.0
# 242  6790.0
# 243  6759.0
# 244  6793.0
#
# [245 rows x 1 columns]

# %%
#importing the preproceesing library
from sklearn.preprocessing import MinMaxScaler,LabelEncoder

# %%
scale=MinMaxScaler()

# %%
lab=LabelEncoder()

# %%
x=scale.fit_transform(x_raw)

# %%
x
# Out:
# array([[0.4984985 , 0.4995005 , 0.48224852],
#        [0.28528529, 0.32467532, 0.30966469],
#        [0.28528529, 0.30669331, 0.30769231],
#        [0.32132132, 0.33066933, 0.34812623],
#        [0.3043043 , 0.36463536, 0.32051282],
#        [0.3973974 , 0.3976024 , 0.39447732],
#        [0.37437437, 0.38561439, 0.39349112],
#        [0.4034034 , 0.40659341, 0.41321499],
#        [0.40540541, 0.41758242, 0.39940828],
#        [0.31331331, 0.33366633, 0.34122288],
#        [0.34834835, 0.35364635, 0.36193294],
#        [0.34534535, 0.34765235, 0.37080868],
#        [0.34834835, 0.36363636, 0.38362919],
#        [0.38238238, 0.38761239, 0.39250493],
#        [0.3033033 , 0.30669331, 0.25641026],
#        [0.27727728, 0.3046953 , 0.30276134],
#        [0.30630631, 0.34465534, 0.33727811],
#        [0.14214214, 0.17182817, 0.15088757],
#        [0.06606607, 0.07692308, 0.0729783 ],
#        [0.07207207, 0.07692308, 0.0887574 ],
#        [0.08308308, 0.12687313, 0.117357  ],
# ...

# %%
x.shape,y.shape
# Out:
# ((245, 3), (245,))

# %%
#splitting the dataset
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.4)

# %%
x_train.shape,y_train.shape
# Out:
# ((147, 3), (147,))

# %%
#importing the machine-learning libraries
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
print("the predicted output for the gold value is:",r2_score(y_test,y_pred))
# Out:
# the predicted output for the gold value is: 0.8716628211221216
