# %%
#importing the modules
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#importing the dataset
ds=pd.read_csv('gold.csv')

# %%
ds
# Out:
#            Date    Open    High     Low   Close  Adj Close  Volume
# 0    2022-06-13  6346.0  6350.0  6295.0  6323.0     6323.0   17820
# 1    2022-06-14  6133.0  6175.0  6120.0  6165.0     6165.0   12430
# 2    2022-06-15  6133.0  6157.0  6118.0  6135.0     6135.0    5470
# 3    2022-06-16  6169.0  6181.0  6159.0  6159.0     6159.0    2630
# 4    2022-06-17  6152.0  6215.0  6131.0  6212.0     6212.0   15660
# ..          ...     ...     ...     ...     ...        ...     ...
# 240  2023-06-05  6778.0  6780.0  6750.0  6761.0     6761.0   56380
# 241  2023-06-06  6776.0  6794.0  6774.0  6781.0     6781.0    5470
# 242  2023-06-07  6795.0  6800.0  6781.0  6790.0     6790.0    4500
# 243  2023-06-08  6746.0  6765.0  6746.0  6759.0     6759.0   21250
# 244  2023-06-09  6773.0  6793.0  6768.0  6793.0     6793.0    8250
#
# [245 rows x 7 columns]

# %%
#checking for the duplicate value
ds.duplicated().sum()
# Out:
# 0

# %%
#checking for the missing value
ds.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
ds.drop(['Date','Volume','Adj Close'],axis=1,inplace=True)

# %%
#Analysing the value using the scatter plot
sns.scatterplot(ds)
# Out:
# <Axes: >

# %%
plt.plot(ds)
plt.grid()

# %%
#opening value
plt.plot(ds['Open'])
plt.title('Opening Value')
plt.grid()

# %%
#closing value
plt.plot(ds['Close'],color='Green')
plt.title('Closing Value')
plt.grid()

# %%
#analysing the value along with barplot
sns.barplot(ds)
# Out:
# <Axes: >

# %%
#to check the value of the price periodically
plt.hist(ds)
# Out:
# (array([[12., 42., 49., 64., 17.,  9.,  6., 10., 15., 21.],
#         [10., 36., 46., 67., 25.,  6.,  8.,  8., 14., 25.],
#         [19., 39., 57., 59., 13.,  7.,  6., 11., 16., 18.],
#         [14., 41., 46., 62., 22.,  8.,  5., 10., 14., 23.]]),
#  array([5806. , 5910.5, 6015. , 6119.5, 6224. , 6328.5, 6433. , 6537.5,
#         6642. , 6746.5, 6851. ]),
#  <a list of 4 BarContainer objects>)
