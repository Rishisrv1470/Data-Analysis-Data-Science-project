# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ds=pd.read_csv('Mall_Customers.csv')

# %%
ds
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
ds.drop(['CustomerID','Gender'],axis=1,inplace=True)

# %%
ds
# Out:
#      Age  Annual Income (k$)  Spending Score (1-100)
# 0     19                  15                      39
# 1     21                  15                      81
# 2     20                  16                       6
# 3     23                  16                      77
# 4     31                  17                      40
# ..   ...                 ...                     ...
# 195   35                 120                      79
# 196   45                 126                      28
# 197   32                 126                      74
# 198   32                 137                      18
# 199   30                 137                      83
#
# [200 rows x 3 columns]

# %%
ds.rename(columns={'Age':'age','Annual Income (k$)':'annual_income','Spending Score (1-100)':'spending_score'},inplace=True)

# %%
ds
# Out:
#      age  annual_income  spending_score
# 0     19             15              39
# 1     21             15              81
# 2     20             16               6
# 3     23             16              77
# 4     31             17              40
# ..   ...            ...             ...
# 195   35            120              79
# 196   45            126              28
# 197   32            126              74
# 198   32            137              18
# 199   30            137              83
#
# [200 rows x 3 columns]

# %%
ds.isnull().sum()
# Out:
# age               0
# annual_income     0
# spending_score    0
# dtype: int64

# %%
ds.duplicated().sum()
# Out:
# 0

# %%
ds.dropna().sum()
# Out:
# age                7770
# annual_income     12112
# spending_score    10040
# dtype: int64

# %%
sns.scatterplot(ds)
# Out:
# <Axes: >

# %%
plt.plot(ds)

# %%
sns.barplot(ds)
# Out:
# <Axes: >

# %%
sns.stripplot(ds)
# Out:
# <Axes: >

# %%
sns.pairplot(ds)

# %%
from sklearn.cluster import KMeans

# %%
kmean=KMeans()

# %%
kmean.fit(ds)
# Out:
# KMeans()

# %%
kmean.cluster_centers_
# Out:
# array([[ 27.10810811,  56.2972973 ,  49.67567568],
#        [ 32.625     ,  80.375     ,  82.9375    ],
#        [ 41.        , 109.7       ,  22.        ],
#        [ 25.27272727,  25.72727273,  79.36363636],
#        [ 56.34090909,  53.70454545,  49.38636364],
#        [ 44.31818182,  25.77272727,  20.27272727],
#        [ 33.        , 114.71428571,  78.42857143],
#        [ 41.23076923,  79.26923077,  15.92307692]])

# %%
kmean.labels_
# Out:
# array([5, 3, 5, 3, 5, 3, 5, 3, 5, 3, 5, 3, 5, 3, 5, 3, 5, 3, 5, 3, 5, 3,
#        5, 3, 5, 3, 5, 3, 5, 3, 5, 3, 5, 3, 5, 3, 5, 3, 5, 3, 4, 3, 5, 0,
#        5, 3, 4, 0, 0, 0, 4, 0, 0, 4, 4, 4, 4, 4, 0, 4, 4, 0, 4, 4, 4, 0,
#        4, 4, 0, 0, 4, 4, 4, 4, 4, 0, 4, 0, 0, 4, 4, 0, 4, 4, 0, 4, 4, 0,
#        0, 4, 4, 0, 4, 0, 0, 0, 4, 0, 4, 0, 0, 4, 4, 0, 4, 0, 4, 4, 4, 4,
#        4, 0, 0, 0, 0, 0, 4, 4, 4, 4, 0, 0, 0, 1, 7, 1, 7, 1, 7, 1, 7, 1,
#        0, 1, 7, 1, 7, 1, 7, 1, 7, 1, 0, 1, 7, 1, 7, 1, 7, 1, 7, 1, 7, 1,
#        7, 1, 7, 1, 7, 1, 7, 1, 7, 1, 7, 1, 7, 1, 7, 1, 7, 1, 7, 1, 7, 1,
#        7, 1, 7, 1, 2, 1, 2, 1, 2, 1, 2, 6, 2, 6, 2, 6, 2, 6, 2, 6, 2, 6,
#        2, 6])

# %%
ds['cluster']=kmean.labels_

# %%
ds
# Out:
#      age  annual_income  spending_score  cluster
# 0     19             15              39        5
# 1     21             15              81        3
# 2     20             16               6        5
# 3     23             16              77        3
# 4     31             17              40        5
# ..   ...            ...             ...      ...
# 195   35            120              79        6
# 196   45            126              28        2
# 197   32            126              74        6
# 198   32            137              18        2
# 199   30            137              83        6
#
# [200 rows x 4 columns]
