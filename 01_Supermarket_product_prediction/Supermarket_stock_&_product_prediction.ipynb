# %%
import pandas as pd
import numpy as np

# %%
ds=pd.read_csv('supermarket_sales - Sheet1.csv')

# %%
ds
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
ds.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count              1000.000000   1000.000000  1000.00000
# mean                  4.761905     15.379369     6.97270
# std                   0.000000     11.708825     1.71858
# min                   4.761905      0.508500     4.00000
# ...

# %%
ds.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
ds.duplicated().sum()
# Out:
# 0

# %%
import seaborn as sns

# %%
sns.heatmap(ds.corr())
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_1788\824282983.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(ds.corr())
# <Axes: >

# %%
sns.countplot(data=ds,y='Product line')
# Out:
# <Axes: xlabel='count', ylabel='Product line'>

# %%
sns.countplot(data=ds,x='City')
# Out:
# <Axes: xlabel='City', ylabel='count'>

# %%
sns.countplot(data=ds,x='Branch')
# Out:
# <Axes: xlabel='Branch', ylabel='count'>

# %%
sns.countplot(data=ds,x='Customer type')
# Out:
# <Axes: xlabel='Customer type', ylabel='count'>

# %%
sns.countplot(data=ds,x='Gender')
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.countplot(data=ds,x='Payment')
# Out:
# <Axes: xlabel='Payment', ylabel='count'>

# %%
sns.scatterplot(data=ds,x='Unit price',y='Total')
# Out:
# <Axes: xlabel='Unit price', ylabel='Total'>

# %%
sns.lineplot(data=ds,x='Unit price',y='Total')
# Out:
# <Axes: xlabel='Unit price', ylabel='Total'>

# %%
sns.pointplot(data=ds,y='Product line',x='Total')
# Out:
# <Axes: xlabel='Total', ylabel='Product line'>

# %%
sns.boxplot(data=ds,y='Rating',x='Gender')
# Out:
# <Axes: xlabel='Gender', ylabel='Rating'>

# %%
sns.boxplot(data=ds,y='Product line',x='Quantity')
# Out:
# <Axes: xlabel='Quantity', ylabel='Product line'>

# %%
sns.lineplot(data=ds,y='Product line',x='Quantity')
# Out:
# <Axes: xlabel='Quantity', ylabel='Product line'>

# %%
sns.barplot(data=ds,x='Branch',y='Rating')
# Out:
# <Axes: xlabel='Branch', ylabel='Rating'>

# %%
sns.barplot(data=ds,x='City',y='Rating')
# Out:
# <Axes: xlabel='City', ylabel='Rating'>

# %%
sns.barplot(data=ds,x='Customer type',y='Rating')
# Out:
# <Axes: xlabel='Customer type', ylabel='Rating'>

# %%
sns.barplot(data=ds,x='Gender',y='Rating')
# Out:
# <Axes: xlabel='Gender', ylabel='Rating'>

# %%
sns.barplot(data=ds,y='Product line',x='Rating')
# Out:
# <Axes: xlabel='Rating', ylabel='Product line'>

# %%
sns.barplot(data=ds,x='Payment',y='Rating')
# Out:
# <Axes: xlabel='Payment', ylabel='Rating'>

# %%
sns.lineplot(data=ds,x='Tax 5%',y='Total')
# Out:
# <Axes: xlabel='Tax 5%', ylabel='Total'>

# %%
sns.scatterplot(data=ds,x='Tax 5%',y='Total')
# Out:
# <Axes: xlabel='Tax 5%', ylabel='Total'>

# %%
sns.lineplot(data=ds,x='gross income',y='Total')
# Out:
# <Axes: xlabel='gross income', ylabel='Total'>

# %%
sns.scatterplot(data=ds,x='gross income',y='Total')
# Out:
# <Axes: xlabel='gross income', ylabel='Total'>

# %%
sns.pairplot(ds)
