# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ds=pd.read_csv('newiitrec.csv')

# %%
ds
# Out:
#      Unnamed: 0       Student Name Date of Birth          Field of Study  \
# 0        165527       Bryan Rogers     1/19/2006        Computer Science
# 1        635763        James Hogan     5/23/1999  Mechanical Engineering
# 2        740021         Student ID     12/2/1997       Civil Engineering
# 3        433076       Susan Miller    10/30/1999        Computer Science
# 4        441628    Brittany Martin     1/10/1998    Chemical Engineering
# ..          ...                ...           ...                     ...
# 212      206456      Robert Norton      3/3/1999       Civil Engineering
# 213      704441    Anthony Simmons     9/11/2001    Chemical Engineering
# 214      543045    Vincent Merritt     10/4/2000       Civil Engineering
# 215      746447   Cynthia Martinez      9/5/2000    Chemical Engineering
# 216      122265  Danielle Matthews     12/8/2002  Mechanical Engineering
#
#      Year of Admission  Expected Year of Graduation  Current Semester  \
# ...

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 217 entries, 0 to 216
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   217 non-null    int64
#  1   Student Name                 217 non-null    object
#  2   Date of Birth                217 non-null    object
#  3   Field of Study               217 non-null    object
#  4   Year of Admission            217 non-null    int64
#  5   Expected Year of Graduation  217 non-null    int64
#  6   Current Semester             217 non-null    int64
#  7   Specialization               217 non-null    object
#  8   Fees                         217 non-null    int64
#  9   Discount on Fees             217 non-null    int64
# dtypes: int64(6), object(4)
# memory usage: 17.1+ KB

# %%
ds.describe()
# Out:
#           Unnamed: 0  Year of Admission  Expected Year of Graduation  \
# count     217.000000         217.000000                   217.000000
# mean   544207.322581        2018.981567                  2019.958525
# std    264321.886622           2.097095                     1.982127
# min    109669.000000        2015.000000                  2017.000000
# 25%    302083.000000        2017.000000                  2018.000000
# 50%    544867.000000        2019.000000                  2020.000000
# 75%    748986.000000        2021.000000                  2022.000000
# max    995738.000000        2022.000000                  2024.000000
#
#        Current Semester           Fees  Discount on Fees
# count        217.000000     217.000000        217.000000
# mean           2.373272  123995.875576      12805.760369
# std            1.098747   43513.486842       9101.769729
# min            1.000000   52994.000000         48.000000
# 25%            1.000000   85212.000000       5542.000000
# ...

# %%
ds.isnull().sum()
# Out:
# Unnamed: 0                     0
# Student Name                   0
# Date of Birth                  0
# Field of Study                 0
# Year of Admission              0
# Expected Year of Graduation    0
# Current Semester               0
# Specialization                 0
# Fees                           0
# Discount on Fees               0
# dtype: int64

# %%
ds.duplicated().sum()
# Out:
# 0

# %%
sns.heatmap(ds.corr())
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_2260\824282983.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(ds.corr())
# <Axes: >

# %%
sns.barplot(data=ds,y=ds['Specialization'],x=ds['Year of Admission'])
# Out:
# <Axes: xlabel='Year of Admission', ylabel='Specialization'>

# %%
sns.lineplot(data=ds,x='Year of Admission',y='Fees')
# Out:
# <Axes: xlabel='Year of Admission', ylabel='Fees'>

# %%
sns.pointplot(data=ds,x='Year of Admission',y='Fees')
# Out:
# <Axes: xlabel='Year of Admission', ylabel='Fees'>

# %%
sns.lineplot(data=ds,x=ds['Year of Admission'],y=ds['Discount on Fees'])
# Out:
# <Axes: xlabel='Year of Admission', ylabel='Discount on Fees'>

# %%
sns.pointplot(data=ds,x=ds['Year of Admission'],y=ds['Discount on Fees'])
# Out:
# <Axes: xlabel='Year of Admission', ylabel='Discount on Fees'>

# %%
sns.barplot(data=ds,y='Specialization',x='Fees')
# Out:
# <Axes: xlabel='Fees', ylabel='Specialization'>

# %%
sns.barplot(data=ds,y='Specialization',x='Discount on Fees')
# Out:
# <Axes: xlabel='Discount on Fees', ylabel='Specialization'>

# %%
sns.lineplot(ds,x=ds['Fees'],y=ds['Discount on Fees'])
# Out:
# <Axes: xlabel='Fees', ylabel='Discount on Fees'>

# %%
sns.scatterplot(ds,x=ds['Fees'],y=ds['Discount on Fees'])
# Out:
# <Axes: xlabel='Fees', ylabel='Discount on Fees'>

# %%
y=ds[['Fees']].values

# %%
x=ds[['Discount on Fees']].values

# %%
y=y.ravel()

# %%
y.shape,x.shape
# Out:
# ((217,), (217, 1))

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
x_train.shape,y_train.shape
# Out:
# ((151, 1), (151,))

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
print(r2_score(y_test,y_pred))
# Out:
# 0.34336046803203213
